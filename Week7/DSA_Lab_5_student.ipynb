# %% [markdown]
# # Lab 5: Linked Lists

# %% [markdown]
# Instructor: Sirasit Lochanachit
#
# Course: 01526102 Data Sturctures and Algorithms

# %% [markdown]
# # Implementing a Node for Linked Lists (Example)

# %% [markdown]
# A node has only two instance variables: `_element` and `_next`.
#
# 1. The `_element` variable is a reference to values/elements stored.
# 2. The `_next` member points to the subsequent node.

# %%
class _Node:
  """Lightweight, nonpublic class for storing a singly linked node."""
  __slots__ = '_element' , '_next'    # streamline memory usage for large number of instances/nodes

  def __init__ (self, element, next):   # initialize node’s fields/properties/attributes
    self._element = element             # reference to user’s element
    self._next = next                   # reference to next node

# %% [markdown]
# # 1. Singly Linked List

# %% [markdown]
# Given an example of a Singly Linked List below, the root node has two instance variables: `_count` and `_head` whereas a data node has two instance variables: `_name` and `_next`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Define a Singly Linked List class and DataNode class

# %%
class SinglyLinkedListBase:
    def __init__(self):
        self._count = 0
        self._head = None

class DataNode:
    def __init__(self, name, next):
        self._name = name
        self._next = next

# %% [markdown]
# Example of creating SinglyLinkedList and DataNode instances
#
# ![image.png](attachment:image.png)

# %%
myList = SinglyLinkedListBase()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pNew = DataNode("John", None)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myList._head = pNew
myList._count += 1

# %%
print("Head node is: " + myList._head._name)
print(f"Node count: {myList._count}")
# Out:
# Head node is: John
# Node count: 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pNew2 = DataNode("Tony", None)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myList._head._next = pNew2
myList._count += 1

# %%
print("Head node is: " + myList._head._name)
print(f"Next node is: {myList._head._next._name}")
print(f"Node count: {myList._count}")
# Out:
# Head node is: John
# Next node is: Tony
# Node count: 2

# %% [markdown]
# # Lab 5-1

# %% [markdown]
# Implement 5 Singly Linked List Operations in a SinglyLinkedList class
# * traverse(): Print all names in the list in a sequential order
#   * If a list is empty, print "This is an empty list"
#   * Create `current` pointer to keep track of the current node while traversing
# * insertFront(data): Create new data node and insert this node at the front of the linked list
# * insertLast(data): Create new data node and insert this node at the back of the linked list
# * insertBefore(node_name, data): Create new data node and insert this node before the given node in the linked list
#   * If a given node is not found in the linked list, print "Cannot insert, <node_name> does not exist."
#   * Create `prev` and `current` variables to keep track of the node before and the given node.
# * delete(data): Delete a node correspond to the given data from the linked list
#   * If a given node is not found in the linked list, print "Cannot delete, <node_name> does not exists."
#   * Create `prev` pointer to keep track of the node before the deleted node
#   * Create `current` pointer variable to keep track of the next node after the deleted node.

# %%
class SinglyLinkedList(SinglyLinkedListBase):       # Extend from SinglyLinkedListBase class defined earlier

    #self._count = 0        Inherited from SinglyLinkedListBase class
    #self._head = None      Inherited from SinglyLinkedListBase class

    def traverse(self):
        current = None
        if self._head is None:
            print("This is an empty list.")

        ########################
        ## Add your code here
        ########################
        pass

    def insertFront(self, data):
        pNew = DataNode(data, None)
        ########################
        ## Add your code here
        ########################
        pass

    def insertLast(self, data):
        pNew = DataNode(data, None)
        ########################
        ## Add your code here
        ########################
        pass

    def insertBefore(self, node_name, data):
        pNew = DataNode(data, None)
        ########################
        ## Add your code here
        ########################
        pass

    def delete(self, data):
        ########################
        ## Add your code here
        ########################
        pass
    
    def getSize(self):
        # eg., list1.getSize()
        return self._count

# %% [markdown]
# ## Testing codes

# %%
list1 = SinglyLinkedList()

list1.traverse()

list1.insertBefore("Kim", "Ko")

print("Add John...")
list1._head = DataNode("John", None)
list1._count += 1

print("Head node is: " + list1._head._name)
print(f"Node count: {list1.getSize()}")
# Out:
# Traverse :  This is an empty list.
#
# Cannot insert Ko ,  Kim does not exist.
# Add John...
# Head node is: John
# Node count: 1

# %%
print("Add Tony...")
pNew = DataNode("Tony", None)
print("Address of Node-Tony: ", hex(id(pNew)))
list1._head._next = pNew
print("Value of list1.head.next: ", list1._head._next)
list1._count += 1

print(f"Next node is: {list1._head._next._name}")
print(f"Node count: {list1.getSize()}")
# Out:
# Add Tony...
# Address of Node-Tony:  0x1e99fbcd720
# Value of list1.head.next:  <__main__.DataNode object at 0x000001E99FBCD720>
# Next node is: Tony
# Node count: 2

# %%
list1.traverse()
# Out:
# Traverse :  John -> Tony

# %%
print("Add Bill...")
pNew = DataNode("Bill", None)
list1._head._next._next = pNew
list1._count += 1

print(f"Next node is: {list1._head._next._name}")
print(f"Node count: {list1.getSize()}")
# Out:
# Add Bill...
# Next node is: Tony
# Node count: 3

# %%
list1.traverse()
# Out:
# Traverse :  John -> Tony -> Bill

# %%
list1.insertFront("Kim")
list1.traverse()
# Out:
# Traverse :  Kim -> John -> Tony -> Bill

# %%
list1.insertLast("Max")
list1.traverse()
# Out:
# Traverse :  Kim -> John -> Tony -> Bill -> Max

# %%
list1.insertBefore("Tony", "Andy")
list1.traverse()
# Out:
# Traverse :  Kim -> John -> Andy -> Tony -> Bill -> Max

# %%
list1.insertBefore("Kim", "Boyz")
list1.traverse()
# Out:
# Traverse :  Boyz -> Kim -> John -> Andy -> Tony -> Bill -> Max

# %%
list1.insertBefore("Kimmy", "Mike")
list1.traverse()
# Out:
# Cannot insert Mike ,  Kimmy does not exist.
# Traverse :  Boyz -> Kim -> John -> Andy -> Tony -> Bill -> Max

# %%
list1.delete("Kim")
list1.traverse()
# Out:
# Traverse :  Boyz -> John -> Andy -> Tony -> Bill -> Max

# %%
list1.delete("Boyz")
list1.traverse()
# Out:
# Traverse :  John -> Andy -> Tony -> Bill -> Max

# %%
list1.delete("Boy")
list1.traverse()
# Out:
# Cannot delete,  Boy does not exist.
# Traverse :  John -> Andy -> Tony -> Bill -> Max

# %%
list1.insertFront("Anna")
list1.traverse()
# Out:
# Traverse :  Anna -> John -> Andy -> Tony -> Bill -> Max

# %%
print(f"Node count: {list1.getSize()}")
# Out:
# Node count: 6

# %%
list1.insertLast("Joe")
list1.traverse()
# Out:
# Traverse :  Anna -> John -> Andy -> Tony -> Bill -> Max -> Joe

# %%
print(f"Node count: {list1.getSize()}")
# Out:
# Node count: 7

# %% [markdown]
# # Lab 5-2

# %% [markdown]
# # 2. Implement a LIFO stack using Singly Linked List

# %% [markdown]
# For this implementation, the __top of stack is the head of the list__.
#
# ---
#
# Each stack instance maintains two variables.
# 1.   The `_head` member is a reference to the node at the head of the list (or None, if the stack is empty).
# 2.   The `_size` instance variable keeps track the current number of elements.
#   * Otherwise, we need to search through the entire list to count the number of
# elements when reporting the stack's size.

# %%
class NumberNode:
    def __init__(self, element, next):
        self._element = element
        self._next = next

# %%
class LinkedStack:
    """LIFO Stack implementation using a singly linked list for storage."""
    
    def __init__(self):
        """ Create an empty stack. """
        self._head = None                      # reference to the head node
        self._size = 0                        # number of stack elements
    
    def __len__(self):
        """ Return the number of elements in the stack. """
        return self._size
  
    def is_empty(self):
        """ Return True if the stack is empty."""
        return self._size == 0
  
    def push(self, e):
        """ Add element e to the top of the stack as a new head node. """
        ########################
        ## Add your code here
        ########################
        pass
  
    def top(self):
        """ Return (but not remove) the element at the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        ########################
        ## Add your code here
        ########################
        pass
  
    def pop(self):
        """ Remove and return the element from the top of the stack.

        Raise Empty exception if the stack is empty.
        """
        ########################
        ## Add your code here
        ########################
        pass
    
    def printStack(self):
        ########################
        ## Add your code here
        ########################
        pass

# %%
class Empty(Exception):
  """ Error attempting to access an element from an empty container. """
  pass

# %% [markdown]
# Push 2 elements into the stack.

# %%
S = LinkedStack()  # contents: []
S.push(7)         # contents: [7]
S.push(5)         # contents: [5, 7]
print('Number of elements: {}'.format(len(S)))     # contents: [5, 7]
# Out:
# Number of elements: 2

# %%
S.printStack()
# Out:
# 5 -> 7

# %% [markdown]
# Pop elements and check whether stack is empty

# %%
print('Remove item: {}'.format(S.pop()))          # contents: [7]
print('Is stack empty?: {}'.format(S.is_empty())) # contents: [7]
print('Remove item: {}'.format(S.pop()))          # contents: []
print('Is stack empty?: {}'.format(S.is_empty())) # contents: []
# Out:
# Remove item: 5
# Is stack empty?: False
# Remove item: 7
# Is stack empty?: True

# %%
S.printStack()
# Out:
# This is an empty stack.

# %% [markdown]
# Attempting to remove or retrieve item when stack is empty

# %%
print(S.pop())    # contents: []
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# c:\Users\zirb\Downloads\Data Structures and Algorithm\01-2023\Lab\Lab5\DSA_Lab_5.ipynb Cell 59 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> print(S.pop())
#
# c:\Users\zirb\Downloads\Data Structures and Algorithm\01-2023\Lab\Lab5\DSA_Lab_5.ipynb Cell 59 in LinkedStack.pop(self)
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=32'>33</a> """ Remove and return the element from the top of the stack.
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=33'>34</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=34'>35</a> Raise Empty exception if the stack is empty.
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=35'>36</a> """
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=36'>37</a> if self.is_empty():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=37'>38</a>     raise Empty('Stack is empty')
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=38'>39</a> answer = self._head._element
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y112sZmlsZQ%3D%3D?line=39'>40</a> self._head = self._head._next    # Set head pointer to the next top node
#
# Empty: Stack is empty

# %%
print(S.top())    # contents: []
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# c:\Users\zirb\Downloads\Data Structures and Algorithm\01-2023\Lab\Lab5\DSA_Lab_5.ipynb Cell 60 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> print(S.top())
#
# c:\Users\zirb\Downloads\Data Structures and Algorithm\01-2023\Lab\Lab5\DSA_Lab_5.ipynb Cell 60 in LinkedStack.top(self)
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=23'>24</a> """ Return (but not remove) the element at the top of the stack.
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=24'>25</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=25'>26</a> Raise Empty exception if the stack is empty.
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=26'>27</a> """
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=27'>28</a> if self.is_empty():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=28'>29</a>     raise Empty('Stack is empty')
#      <a href='vscode-notebook-cell:/c%3A/Users/zirb/Downloads/Data%20Structures%20and%20Algorithm/01-2023/Lab/Lab5/DSA_Lab_5.ipynb#Y114sZmlsZQ%3D%3D?line=29'>30</a> return self._head._element
#
# Empty: Stack is empty

# %% [markdown]
# Push more elements into stack, then pop one element

# %%
S.push(2)         # contents = [2]
S.push(4)         # contents = [4, 2]
print('Retrieve top item: {}'.format(S.top()))    # contents = [4, 2]
S.push(6)                                         # contents = [6, 4, 2]
print('Number of elements: {}'.format(len(S)))    # contents = [6, 4, 2]
print('Remove item: {}'.format(S.pop()))          # contents = [4, 2]
S.push(1)         # contents = [1, 4, 2]
# Out:
# Retrieve top item: 4
# Number of elements: 3
# Remove item: 6

# %%
S.printStack()
# Out:
# 1 -> 4 -> 2
