# %% [markdown]
# # Tutorial: Global Variables and Timeit
#
# Lecturer: <code>Sirasit Lochanachit</code>
#
# Course:
#
# <code>01526121 Data Structures and Algorithms [SIIE]
# </code>
#
# Term: <code>02/2025</code>
#
# Special thanks to TA <code>Sasithorn</code> for written up this tutorial.
#
# ---

# %% [markdown]
# # **GLOBAL + LOCAL + TIMEIT**
#
# (little exercises to warm up your coding)

# %% [markdown]
# # 1. Variable Scope

# %% [markdown]
# ## 1.1 Global variable

# %% [markdown]
# This creates/declares a global variable `x`

# %%
x = 999

# %%
def number():
    print(x)


number()
# Out:
# 999

# %% [markdown]
# - Any function can *read* global variables
# - This result show you that  `number()` function can access the global variable `x`

# %% [markdown]
# ## 1.2 Local variable

# %%
def localnum():
    y = 999
    print(y)

# %% [markdown]
# - `y` variable is local to localnum()
# - It only exists while the function is executing

# %%
localnum()
# Out:
# 999

# %% [markdown]
# 👉 Try to show `y` outside the function

# %%
print(y)

# %% [markdown]
# - local variables do not exist outside the function that created them

# %% [markdown]
# # 2. Modifying Global Variables

# %%
x = 999

# %%
def editpls():
    x = x + 1
    print(x)

# %% [markdown]
# 👉 Try to modify variable `x` by executing  the function

# %%
editpls()

# %% [markdown]
# - Python assumes variable `x` is local, but local variable `x` has no value yet

# %% [markdown]
# ## 2.1 Declaring a Global Variable for Modification
#
# Use `global` when we want to modify a variable that was defined outside the function (global scope)

# %%
z = 999

# %%
def plus():
    global z
    z = z + 1

# %%
plus()

# %%
z
# Out:
# 1000

# %% [markdown]
# what if we want z to be 9999?

# %%
z = 999

# %%
def plus_v2():
    #######################
    # your code here
    #######################
    pass  # Remove this line

# %%
plus_v2()
z
# Out:
# 9999

# %% [markdown]
# # 2.2 globals() function

# %% [markdown]
# It returns a dictionary of every variables defined in this module.

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'x = 5\n\ndef number():\n  print(x)\n\nnumber()',
#   'x = 999\n\ndef number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'print(y)',
#   'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)\n\n    editpls()',
#   'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'x = 999',
#   'def number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'localnum()',
#   'print(y)',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'editpls()',
#   'z = 999\n\ndef plus():\n  global z\n  sum = z + 1',
#   'plus()',
#   'plus()\nplus()',
#   'plus()',
#   'z',
#   'z = 999\n\ndef plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'def plus():\n  global z\n  z = z + 9000',
#   'z',
#   'plus()\nz',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   '# or\nplus() * 9000',
#   'def plus():\n  globals()\n  z = z + 1',
#   'plus()',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'print(globals())',
#   'globals()',
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   'import timeit',
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def fib(n):\n    if n == 0:\n        return 0\n    elif n == 1:\n        return 1\n    else:\n        return fib(n-1) + fib(n-2)',
#   'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n  return out',
#   'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n   return out',
#   'sum1(9)',
#   'sum1(10)',
#   'sum1(11)',
#   'sum1(10)',
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'x = 999',
#   'def number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'print(y)',
#   'editpls()',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()',
#   "# don't forget to import this module before using them\nimport timeit",
#   "timeit.timeit('sum(range(1000))', number=1000)",
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'x = 999',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'editpls()',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()',
#   "# don't forget to import this module before using them\nimport timeit",
#   "timeit.timeit('sum(range(1000))', number=1000)",
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()'],
#  '_oh': {21: 999,
#   24: 1000,
#   28: 1000,
#   30: 1000,
#   31: 10000,
#   34: 9999,
#   41: {...},
#   44: 0.021342998000363878,
#   45: [0.019940721000239137,
#    0.055174878999878274,
#    0.0594251920001625,
#    0.08426758599989626,
#    0.10084500400034813,
#    0.12428392100036945,
#    0.14337541999975656,
#    0.16280602400001953,
#    0.186474662999899,
#    0.2193981100003839],
#   50: 36,
#   51: 45,
#   52: 55,
#   53: 45,
#   55: 55,
#   58: 55,
#   70: 19001,
#   73: 9999,
#   74: {...},
#   76: 0.018851071999961277,
#   77: 0.0187532910003938,
#   78: [0.0216593200002535,
#    0.05067349400087551,
#    0.06867652999972051,
#    0.08181371499995294,
#    0.10225010199974349,
#    0.13977231699936965,
#    0.26875663600003463,
#    0.27065956799924606,
#    0.19172998700014432,
#    0.37730348900004174],
#   80: 55,
#   82: 55,
#   90: 9999,
#   91: {...},
#   93: 0.02006669399997918,
#   94: 0.02214425900092465,
#   95: [0.02353484900049807,
#    0.0474726489992463,
#    0.060714534998624003,
#    0.10320253499958199,
#    0.10671355600061361,
#    0.1257071050004015,
#    0.14492408800106205,
#    0.16232989200034353,
#    0.18577984900002775,
#    0.20729695800037007],
#   97: 55,
#   99: 55,
#   105: 1000,
#   108: 9999},
#  '_dh': ['/content'],
#  'In': ['',
#   'x = 5\n\ndef number():\n  print(x)\n\nnumber()',
#   'x = 999\n\ndef number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'print(y)',
#   'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)\n\n    editpls()',
#   'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'x = 999',
#   'def number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'localnum()',
#   'print(y)',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'editpls()',
#   'z = 999\n\ndef plus():\n  global z\n  sum = z + 1',
#   'plus()',
#   'plus()\nplus()',
#   'plus()',
#   'z',
#   'z = 999\n\ndef plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'def plus():\n  global z\n  z = z + 9000',
#   'z',
#   'plus()\nz',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   '# or\nplus() * 9000',
#   'def plus():\n  globals()\n  z = z + 1',
#   'plus()',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'print(globals())',
#   'globals()',
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   'import timeit',
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def fib(n):\n    if n == 0:\n        return 0\n    elif n == 1:\n        return 1\n    else:\n        return fib(n-1) + fib(n-2)',
#   'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n  return out',
#   'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n   return out',
#   'sum1(9)',
#   'sum1(10)',
#   'sum1(11)',
#   'sum1(10)',
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'x = 999',
#   'def number():\n  print(x)\n\nnumber()',
#   'def localnum():\n  y = 999\n  print(y)',
#   'localnum()',
#   'print(y)',
#   'editpls()',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()',
#   "# don't forget to import this module before using them\nimport timeit",
#   "timeit.timeit('sum(range(1000))', number=1000)",
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'x = 999',
#   'def editpls():\n    x = x + 1\n    print(x)',
#   'editpls()',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()',
#   "# don't forget to import this module before using them\nimport timeit",
#   "timeit.timeit('sum(range(1000))', number=1000)",
#   "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#   "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#   'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#   'sum1(10)',
#   'def sum2(n):\n  return sum(range(n+1))',
#   'sum2(10)',
#   "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#   "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 1',
#   'plus()',
#   'z',
#   'z = 999',
#   'def plus():\n  global z\n  z = z + 9000',
#   'plus()\nz',
#   'globals()'],
#  'Out': {21: 999,
#   24: 1000,
#   28: 1000,
#   30: 1000,
#   31: 10000,
#   34: 9999,
#   41: {...},
#   44: 0.021342998000363878,
#   45: [0.019940721000239137,
#    0.055174878999878274,
#    0.0594251920001625,
#    0.08426758599989626,
#    0.10084500400034813,
#    0.12428392100036945,
#    0.14337541999975656,
#    0.16280602400001953,
#    0.186474662999899,
#    0.2193981100003839],
#   50: 36,
#   51: 45,
#   52: 55,
#   53: 45,
#   55: 55,
#   58: 55,
#   70: 19001,
#   73: 9999,
#   74: {...},
#   76: 0.018851071999961277,
#   77: 0.0187532910003938,
#   78: [0.0216593200002535,
#    0.05067349400087551,
#    0.06867652999972051,
#    0.08181371499995294,
#    0.10225010199974349,
#    0.13977231699936965,
#    0.26875663600003463,
#    0.27065956799924606,
#    0.19172998700014432,
#    0.37730348900004174],
#   80: 55,
#   82: 55,
#   90: 9999,
#   91: {...},
#   93: 0.02006669399997918,
#   94: 0.02214425900092465,
#   95: [0.02353484900049807,
#    0.0474726489992463,
#    0.060714534998624003,
#    0.10320253499958199,
#    0.10671355600061361,
#    0.1257071050004015,
#    0.14492408800106205,
#    0.16232989200034353,
#    0.18577984900002775,
#    0.20729695800037007],
#   97: 55,
#   99: 55,
#   105: 1000,
#   108: 9999},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <google.colab._shell.Shell object at 0x7bf909f9d850>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7bf909f9caa0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7bf909f9caa0>,
#  '_': 9999,
#  '__': 1000,
#  '___': 55,
#  '_i': 'plus()\nz',
#  '_ii': 'def plus():\n  global z\n  z = z + 9000',
#  '_iii': 'z = 999',
#  '_i1': 'x = 5\n\ndef number():\n  print(x)\n\nnumber()',
#  'x': 999,
#  'number': <function __main__.number()>,
#  '_i2': 'x = 999\n\ndef number():\n  print(x)\n\nnumber()',
#  '_i3': 'def localnum():\n  y = 999\n  print(y)',
#  'localnum': <function __main__.localnum()>,
#  '_i4': 'localnum()',
#  '_i5': 'print(y)',
#  '_i6': 'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)\n\n    editpls()',
#  'editpls': <function __main__.editpls()>,
#  '_i7': 'x = 999\n\ndef editpls():\n    x = x + 1\n    print(x)',
#  '_i8': 'def editpls():\n    x = x + 1\n    print(x)',
#  '_i9': 'x = 999',
#  '_i10': 'def number():\n  print(x)\n\nnumber()',
#  '_i11': 'def localnum():\n  y = 999\n  print(y)',
#  '_i12': 'localnum()',
#  '_i13': 'localnum()',
#  '_i14': 'print(y)',
#  '_i15': 'def editpls():\n    x = x + 1\n    print(x)',
#  '_i16': ' editpls()',
#  '_i17': 'z = 999\n\ndef plus():\n  global z\n  sum = z + 1',
#  'z': 9999,
#  'plus': <function __main__.plus()>,
#  '_i18': 'plus()',
#  '_i19': 'plus()\nplus()',
#  '_i20': 'plus()',
#  '_i21': 'z',
#  '_21': 999,
#  '_i22': 'z = 999\n\ndef plus():\n  global z\n  z = z + 1',
#  '_i23': 'plus()',
#  '_i24': 'z',
#  '_24': 1000,
#  '_i25': 'z = 999',
#  '_i26': 'def plus():\n  global z\n  z = z + 1',
#  '_i27': 'plus()',
#  '_i28': 'z',
#  '_28': 1000,
#  '_i29': 'def plus():\n  global z\n  z = z + 9000',
#  '_i30': 'z',
#  '_30': 1000,
#  '_i31': 'plus()\nz',
#  '_31': 10000,
#  '_i32': 'z = 999',
#  '_i33': 'def plus():\n  global z\n  z = z + 9000',
#  '_i34': 'plus()\nz',
#  '_34': 9999,
#  '_i35': '# or\nplus() * 9000',
#  '_i36': 'def plus():\n  globals()\n  z = z + 1',
#  '_i37': 'plus()',
#  '_i38': 'def plus():\n  global z\n  z = z + 1',
#  '_i39': 'plus()',
#  '_i40': 'print(globals())',
#  '_i41': 'globals()',
#  '_41': {...},
#  '_i42': "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#  '_i43': 'import timeit',
#  'timeit': <module 'timeit' from '/usr/lib/python3.12/timeit.py'>,
#  '_i44': "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#  '_44': 0.021342998000363878,
#  '_i45': "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#  '_45': [0.019940721000239137,
#   0.055174878999878274,
#   0.0594251920001625,
#   0.08426758599989626,
#   0.10084500400034813,
#   0.12428392100036945,
#   0.14337541999975656,
#   0.16280602400001953,
#   0.186474662999899,
#   0.2193981100003839],
#  '_i46': 'def fib(n):\n    if n == 0:\n        return 0\n    elif n == 1:\n        return 1\n    else:\n        return fib(n-1) + fib(n-2)',
#  'fib': <function __main__.fib(n)>,
#  '_i47': 'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n  return out',
#  '_i49': 'def sum1(n):\n   out = 0\n   for i in range(n):\n     out += i\n   return out',
#  'sum1': <function __main__.sum1(n)>,
#  '_i50': 'sum1(9)',
#  '_50': 36,
#  '_i51': 'sum1(10)',
#  '_51': 45,
#  '_i52': 'sum1(11)',
#  '_52': 55,
#  '_i53': 'sum1(10)',
#  '_53': 45,
#  '_i54': 'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#  '_i55': 'sum1(10)',
#  '_55': 55,
#  '_i56': 'def sum2(n):\n  return sum(range(n+1))',
#  'sum2': <function __main__.sum2(n)>,
#  '_i57': 'def sum2(n):\n  return sum(range(n+1))',
#  '_i58': 'sum2(10)',
#  '_58': 55,
#  '_i59': "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#  'time1': 0.07343617399965296,
#  'time2': 0.020865750000666594,
#  '_i60': "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#  'n': 10000,
#  'global_time1': 0.05287284699988959,
#  'global_time2': 0.020596434000253794,
#  '_i61': "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#  '_i62': "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#  '_i63': 'x = 999',
#  '_i64': 'def number():\n  print(x)\n\nnumber()',
#  '_i65': 'def localnum():\n  y = 999\n  print(y)',
#  '_i66': 'localnum()',
#  '_i67': 'print(y)',
#  '_i68': ' editpls()',
#  '_i69': 'plus()',
#  '_i70': 'z',
#  '_70': 19001,
#  '_i71': 'z = 999',
#  '_i72': 'def plus():\n  global z\n  z = z + 9000',
#  '_i73': 'plus()\nz',
#  '_73': 9999,
#  '_i74': 'globals()',
#  '_74': {...},
#  '_i75': "# don't forget to import this module before using them\nimport timeit",
#  '_i76': "timeit.timeit('sum(range(1000))', number=1000)",
#  '_76': 0.018851071999961277,
#  '_i77': "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#  '_77': 0.0187532910003938,
#  '_i78': "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#  '_78': [0.0216593200002535,
#   0.05067349400087551,
#   0.06867652999972051,
#   0.08181371499995294,
#   0.10225010199974349,
#   0.13977231699936965,
#   0.26875663600003463,
#   0.27065956799924606,
#   0.19172998700014432,
#   0.37730348900004174],
#  '_i79': 'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#  '_i80': 'sum1(10)',
#  '_80': 55,
#  '_i81': 'def sum2(n):\n  return sum(range(n+1))',
#  '_i82': 'sum2(10)',
#  '_82': 55,
#  '_i83': "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#  '_i84': "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#  '_i85': 'x = 999',
#  '_i86': 'def editpls():\n    x = x + 1\n    print(x)',
#  '_i87': ' editpls()',
#  '_i88': 'z = 999',
#  '_i89': 'def plus():\n  global z\n  z = z + 9000',
#  '_i90': 'plus()\nz',
#  '_90': 9999,
#  '_i91': 'globals()',
#  '_91': {...},
#  '_i92': "# don't forget to import this module before using them\nimport timeit",
#  '_i93': "timeit.timeit('sum(range(1000))', number=1000)",
#  '_93': 0.02006669399997918,
#  '_i94': "timeit.timeit('sum(r)', \n              setup='r = range(1000)', \n              number=1000)",
#  '_94': 0.02214425900092465,
#  '_i95': "[timeit.timeit('sum(r)',\n               setup=f'r = range({n})',\n               number=1000)\n for n in range(1000, 11000, 1000)]",
#  '_95': [0.02353484900049807,
#   0.0474726489992463,
#   0.060714534998624003,
#   0.10320253499958199,
#   0.10671355600061361,
#   0.1257071050004015,
#   0.14492408800106205,
#   0.16232989200034353,
#   0.18577984900002775,
#   0.20729695800037007],
#  '_i96': 'def sum1(n):\n   out = 0\n   for i in range( n+1):\n     out += i\n   return out',
#  '_i97': 'sum1(10)',
#  '_97': 55,
#  '_i98': 'def sum2(n):\n  return sum(range(n+1))',
#  '_i99': 'sum2(10)',
#  '_99': 55,
#  '_i100': "time1 = timeit.timeit(\n    lambda: sum1(10000),\n    number=100\n    )\ntime2 = timeit.timeit(\n    lambda: sum2(10000),\n    number=100\n)\n\nprint('sum1 :', time1)\nprint('sum2 :', time2)",
#  '_i101': "n = 10000\n\nglobal_time1 = timeit.timeit(\n    f'sum1(n)',\n    number=100,\n    globals=globals()\n    )\nglobal_time2 = timeit.timeit(\n    f'sum2(n)',\n    number=100,\n    globals=globals()\n    )\n\nprint('sum1 :', global_time1)\nprint('sum2 :', global_time2)",
#  '_i102': 'z = 999',
#  '_i103': 'def plus():\n  global z\n  z = z + 1',
#  '_i104': 'plus()',
#  '_i105': 'z',
#  '_105': 1000,
#  '_i106': 'z = 999',
#  '_i107': 'def plus():\n  global z\n  z = z + 9000',
#  '_i108': 'plus()\nz',
#  '_108': 9999,
#  '_i109': 'globals()'}

# %% [markdown]
# ---

# %% [markdown]
# # 3. Time

# %% [markdown]
# The [`time`](https://docs.python.org/3/library/time.html#module-time) module contains functions for obtaining and interpreting the current system time (in seconds).
#
# Technically, it is the time since the **epoch**, where time starts in 1 January 1970.
#
# What is the current system time (in seconds)?

# %%
import time

time.time()

# %% [markdown]
# How many years since the epoch?

# %%
time.time() // (365 * 24 * 60 * 60)

# %% [markdown]
# What is the current local time? (Depends on timezone set in your machine)

# %%
time.localtime(time.time())

# %% [markdown]
# By taking start and stop "timestamps", we can measure the runtime of code:

# %%
start_time = time.time()  # Record the starting time
########################
# Run your algorithm
########################
time.sleep(1)
end_time = time.time()  # Record the ending time

running_time = end_time - start_time  # Record time executed

print(f"Time executed: {running_time:.5f} seconds")

# %% [markdown]
# Example: What is the running time for 5<sup>100</sup>?

# %%
start_time = time.time()  # Record the starting time

5**100

end_time = time.time()  # Record the ending time


running_time = end_time - start_time  # Record time executed

print(f"Time executed: {running_time:.5f} seconds")

# %% [markdown]
# How about the running time for 5<sup>1,000</sup>?

# %%
########################
# Your code here
########################

# %% [markdown]
# How about the running time for 5<sup>10,000</sup>?

# %%
########################
# Your code here
########################

# %% [markdown]
# # 4. Building a stopwatch utility
#
# We can build a utility function for timing the execution of a passed-in function:

# %%
def stopwatch(fn):
    start_time = time.time()
    fn()
    end_time = time.time()
    return end_time - start_time

# %% [markdown]
# Can you guess what does this code do?

# %%
sum(range(100000))

# %% [markdown]
# Can you time the execution of this code?

# %%
stopwatch(sum(range(100000)))

# %% [markdown]
# Try again by passing a small anonymous function to another function, which is `lambda` function

# %%
stopwatch(lambda: sum(range(100000)))

# %% [markdown]
# While using a lambda is one possible approach, it limits us to passing in a function that must be called a certain way (e.g., with no arguments).
#
# We can make use of the `eval` function to evaluate an arbitrary string of Python code instead.

# %%
eval("1 + 2")

# %%
eval("sum(range(100000))")

# %%
def stopwatch(stmt="pass"):
    start_time = time.time()
    eval(stmt)
    end_time = time.time()
    return end_time - start_time

# %% [markdown]
# Total timing of 1 round on function

# %%
stopwatch("sum(range(100000))")

# %% [markdown]
# To make timings more stable, we can run the passed-in function __multiple times__:

# %%
def stopwatch_rounds(stmt="pass", number=1):
    total = 0
    for _ in range(number):
        start_time = time.time()
        eval(stmt)
        end_time = time.time()
        total += end_time - start_time
    return total

# %% [markdown]
# Total timing of 1000 rounds on the same function

# %%
stopwatch_rounds("sum(range(10000))", number=1000)

# %% [markdown]
# # 3. timeit

# %% [markdown]
# Instead of manually implementing `stopwatch_rounds` function we can use `timeit` module.
#
# The [`timeit`](https://docs.python.org/3/library/timeit.html) module is a built-in library for measuring the execution of code passed in as a string.
#
#  **Parameters**
# - `stmt`: the code to measure
# - `setup`: code executed once before timing
# - `number`: how many times to run the statement

# %%
# don't forget to import this module before using them
import timeit

# %%
timeit.timeit("sum(range(1000))", number=1000)
# Out:
# 0.018175262999648112

# %%
timeit.timeit("sum(r)", setup="r = range(1000)", number=1000)
# Out:
# 0.02294388500013156

# %% [markdown]
# We can easily use this to gather timings for multiple input values:
#
# For instance, we would like to record the running times for each input of `n` starting from 1000, 2000, 3000, ... , 10000

# %%
[
    timeit.timeit("sum(r)", setup=f"r = range({n})", number=1000)
    for n in range(1000, 11000, 1000)   # i.e. [1000, 2000, 3000, ...., 10000]
]
# Out:
# [0.01811489499959862,
#  0.042368438000266906,
#  0.0602012890012702,
#  0.08563653499913926,
#  0.10355866700047045,
#  0.12393788900044456,
#  0.14309821499955433,
#  0.16115236199948413,
#  0.19600458400054777,
#  0.2072466270001314]

# %% [markdown]
# ## Comparing 2 functions

# %% [markdown]
# First function :
#
# ### Exercise 1: Write a function to sum all of the numbers starting from 0 to `n` using loop

# %%
def sum1(n):
    ############################
    #### Add your code here #####
    #############################
    return total

# %%
sum1(10)
# Out:
# 55

# %% [markdown]
# Second function : Using built-in function

# %%
def sum2(n):
    return sum(range(n + 1))

# %%
sum2(10)
# Out:
# 55

# %% [markdown]
# ### lambda
#
# Using 'lambda' to pass the first sum function into timeit

# %%
time1 = timeit.timeit(lambda: sum1(10000), number=100)

# %% [markdown]
# ### Exercise 2: Pass a second sum function into timeit

# %%
time2 = timeit.timeit(
    #############################
    #### Add your code here #####
    #############################
)

# %%
print("sum1 :", time1)
print("sum2 :", time2)

# %% [markdown]
# ###  string + globals()

# %% [markdown]
# For example, in order to call a custom function `sum1` and  `sum2`, we need to include `globals()`, otherwise it is not available to use in a `timeit` function.

# %%
n = 10000

global_time1 = timeit.timeit(f"sum1(n)", number=100, globals=globals())

global_time2 = timeit.timeit(
    #############################
    #### Add your code here #####
    #############################
)

print("sum1 :", global_time1)
print("sum2 :", global_time2)
# Out:
# sum1 : 0.052824807999058976
# sum2 : 0.020965441999578616

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Write function `sum3` that returns the sum of all integers from 0 to n  by using the following mathematical formula:
#
# $$
# 0 + 1 + 2 + \dots + n = \frac{n(n+1)}{2}
# $$
#
#
# Your function must use the **formula only**   (no loops)

# %%
def sum3(n):
    #############################
    #### Add your code here #####
    #############################
    return total

# %% [markdown]
# **Compare the execution time**
#
# Use `timeit.timeit()` to measure and compare the execution time of `sum1`, `sum2 `and `sum3` on 1000 rounds

# %%
#############################
#### Add your code here #####
#############################
# Out:
# sum1 : 0.08372374100144953
# sum2 : 0.03903122100018663
# sum3 : 2.748299993982073e-05

# %% [markdown]
# ---
