# %% [markdown]
# # Homework 1: Python Revision and Timing
#
# Lecturer: <code>Sirasit Lochanachit</code>
#
# Course:
#
# <code>01526121 Data Structures and Algorithms [SIIE]
# </code>
#
# Term: <code>02/2025</code>
#
# ---

# %% [markdown]
# # Instructions: This homework is required to be submitted during the next lab session only.

# %% [markdown]
# # HW 1
#
# ## Problem Description
# 1. Write a function `minmax_recur(data)` that:
# - Accepts a list of one or more numeric values
# - Returns a tuple of length two `(smallest, largest)`.
# - Uses **recursion** to find the smallest and largest values.
#
# 2. Your function must:
# - Handle cases where the list has only one element.
# - Correctly compute the minimum and maximum for lists with more than one element.
#
# ## Constraints
# - Built-in functions `min()` or `max()` or `sorted()` or `sort()` are not allowed.
# - loops (`for` or `while`) are not allowed.
# - Use `recursion` to traverse the list.

# %%
def minmax_recur(data):
    if not data:
        raise ValueError("Input sequence must contain at least one number.")
    
    ######################
    ## Add your code here
    ######################

    return (smallest, largest)

# %%
# Example inputs and outputs:
print(minmax_recur([3, 1, 4, 1, 5, 9, 2, 6, 5, 3]))  # Output: (1, 9)
print(minmax_recur([-7, -2, -5, -10, 0]))            # Output: (-10, 0)
print(minmax_recur([42]))                            # Output: (42, 42)

# %% [markdown]
# # What is Recursion? (For those who forgot what it is)
# - See more on [Recursion_Interactive_Guide.html](https://github.com/noswolf/DSA_BIT/blob/DSA_25/Week2/Recursion_Interactive_Guide.html)

# %% [markdown]
# ---

# %% [markdown]
# # HW 2: Measure and Comparing Execution Time of Iterative and Recursive `minmax` Functions

# %% [markdown]
# ## 1.
#
# ### Problem Description
#
# Use the `timeit` module to measure the time taken by each version of the `minmax` function for lists of various sizes (e.g., 100, 1,000, 10,000 elements) and analyze the time performance of each approach.
#
# ## Constraints
# - Use the `timeit.timeit` function to measure the time taken by iterative version compared with recursive version.
# - For any list size, the code must generate random numbers between 1 and 1000.
# - Write a list comprehension to record the execution times.
# - In `timeit` function, each size should be executed in `minmax` function for **100 rounds**

# %% [markdown]
# How-to generate a list of 100 random numbers between 1 and 1000 using `random` module:

# %%
list_sizes = [100, 1000, 10000]

import random

# Example: Using list comprehension to generate a list of 100 random numbers between 1 and 1000
test_list = [random.randint(1, 1000) for _ in range(list_sizes[0])]

# %%
test_list

# %% [markdown]
# Check length of `test_list`

# %%
# Length
len(test_list)

# %% [markdown]
# Copy your `minmax_iter` function from Lab 1 and paste it here

# %%
############################
## Add your code here
############################

# %%
import timeit

iterative_times = []
recursive_times = []
list_sizes = [10, 100, 1000, 5000]

# %%
for i, s in enumerate(list_sizes):
    test_list = ## Add your code here
    
    iter_time = timeit.timeit(
        ############################
        ## Add your code here
        ############################
    )
    iterative_times[i].append(iter_time)
    
    recur_time = timeit.timeit(
        ############################
        ## Add your code here
        ############################
    )
    recursive_times[i].append(recur_time)

# %% [markdown]
# ## 2. Use a loop to display the execution times for both approaches in a table-like format.

# %%
######################
## Add your code here
######################

# %% [markdown]
# ### Example Input and Output
#
# For lists of size `[10, 100, 1000]`:

# %% [markdown]
# ```Python
# List size: 10
# Iterative: 0.000012 seconds
# Recursive: 0.000045 seconds
#
# List size: 100
# Iterative: 0.000102 seconds
# Recursive: 0.000875 seconds
#
# List size: 1000
# Iterative: 0.001023 seconds
# Recursive: Stack Overflow (or longer runtime)
# ```

# %% [markdown]
# ---
