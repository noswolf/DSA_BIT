# %% [markdown]
# # Lab 8 Part 2: Sorting

# %% [markdown]
# Lecturer: <code>Sirasit Lochanachit</code>
#
# Course:
#
# <code>01526102 Data Sturctures and Algorithms [SIIE]\
#     06036120 Data Structures and Algorithms Principles [BIT]
# </code>
#
# Term: <code>01/2024</code>
#
# ---

# %% [markdown]
# ## Gentle reminder of Big-O of sorting operations
#
# - Bubble Sort: $O(N^2)$
# - Selection Sort: $O(N^2)$
# - Insertion Sort: $O(N^2)$
# - Merge Sort: $O(N log_2 N)$

# %%
import timeit
import random
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#  # Prerequisite Practice Test

# %% [markdown]
# ## 1. Linear/Sequential Search
#
# Write a linear/sequential search function to search for a target in a given list using **recursion**
# - If a target is found, return `True`
# - If a target is not found, return `False`

# %%
def linear_search_iterative(data, target): 
    for i in range(len(data)): 
        if data[i] == target: 
            return True
    return False

# %%
def linear_search_recursive(data, target): 
    ########################
    ## Add your code here
    ########################
    pass

# %%
data = [10,20,40,50]
linear_search_recursive(data,40)

# %%
linear_search_recursive(data,100)

# %% [markdown]
# If your PC/colab encountered Maximum depth recursion Error, try reduce the max number of input size.

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ns = np.linspace(100, 10_000, 50, dtype=int)

ts_linsearch_iter = [timeit.timeit('linear_search_iterative(lst, lst[-1])',
                              setup=f'lst = list(range({n}))',
                              globals=globals(),
                              number=100)
                for n in ns]

ts_linsearch_recur = [timeit.timeit('linear_search_recursive(lst, lst[-1])',
                              setup=f'lst = list(range({n}))',
                              globals=globals(),
                              number=100)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_linsearch_iter, '.r-') # Square Red
plt.plot(ns, ts_linsearch_recur, '.g-') # Square Green
plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Linear Search Iterative vs Recursive')
plt.legend(['Linear Search Iterative', 'Linear Search Recursive'])

# %% [markdown]
# ## Lab 8-3: Implement Merge Sort in ascending order (lower numbers to higher numbers)

# %% [markdown]
# Two distinct processes:
# 1. Splitting: Requires $\log n$ operations
# 2. Merging: Require $n$ operations
#
# Therefore, a total of $n \log n$ operations, $O(n \log n)$.
#
# Note: mergesort requires extra memory space to hold two halves. This can be a critical factor if the list is large.

# %% [markdown]
# ## 1. Implement Merge Sort using iterative approach (non-recursive)

# %%
def merge_sort_iterative(arr):
    current_size = 1
    
    # Outer loop for traversing each sub array of current_size
    while current_size < len(arr) - 1:
        
        left = 0
        # Inner loop for merge call in a sub array
        # Each complete iteration sorts the iterating sub array
        while left < len(arr)-1:
            # start from leftmost
            # mid index = left index of sub array + current sub array size - 1
            mid = min((left + current_size - 1), (len(arr)-1))
            
            # (False result,True result) for last sub array if length is not even
            right = ((2 * current_size + left - 1, len(arr) - 1)
                     [2 * current_size + left - 1 > len(arr)-1])
            
            # Merge call for each sub array
            print(f'Merging : {arr}')
            merge(arr, left, mid, right)
            left = left + current_size*2
            
        # Increasing sub array size by multiple of 2
        current_size = 2 * current_size

def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
    L = [0] * n1
    R = [0] * n2

    for i in range(0, n1):
        L[i] = arr[l + i]

    for i in range(0, n2):
        R[i] = arr[m + 1 + i]

    i = 0
    j = 0
    k = l

    while i < n1 and j < n2:
        if L[i] > R[j]:
            arr[k] = R[j]
            j += 1
        else:
            arr[k] = L[i]
            i += 1
        k += 1

    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

# %%
# Example usage
data = [12, 11, 13, 5, 6, 7]
print("Original list is:", data)
merge_sort_iterative(data)
print("Sorted list is:", data)
# Out:
# Original list is: [12, 11, 13, 5, 6, 7]
# Merging : [12, 11, 13, 5, 6, 7]
# Merging : [11, 12, 13, 5, 6, 7]
# Merging : [11, 12, 5, 13, 6, 7]
# Merging : [11, 12, 5, 13, 6, 7]
# Merging : [5, 11, 12, 13, 6, 7]
# Merging : [5, 11, 12, 13, 6, 7]
# Sorted list is: [5, 6, 7, 11, 12, 13]

# %% [markdown]
# ## 2. Implement Merge Sort using recursive approach

# %% [markdown]
# Hint: Merging stage can be implemented similar to merging stage from an iterative version.

# %%
def merge_sort_recursive(alist):
    print("Splitting ",alist)
    print("\n")
    if len(alist) > 1:            # len > 1, otherwise, list is sorted

        # Splitting stage

        mid = len(alist) // 2     # Finding the mid of the array
        L = alist[:mid]           # Dividing the elements into 2 halves
        R = alist[mid:]

        merge_sort_recursive(L)              # Sorting the first half
        merge_sort_recursive(R)               # Sorting the second half

        # Merging stage
        
        i = j = k = 0

        ##########################
        ## Add your code here
        ##########################
    
    print("Merging ",alist, "\n")

# %%
# Example usage
data = [12, 11, 13, 5, 6, 7]
print("Original list is:", data)
merge_sort_recursive(data)
print("Sorted list is:", data)
# Out:
# Original list is: [12, 11, 13, 5, 6, 7]
# Splitting  [12, 11, 13, 5, 6, 7]
#
#
# Splitting  [12, 11, 13]
#
#
# Splitting  [12]
#
#
# Merging  [12]
#
# Splitting  [11, 13]
#
#
# Splitting  [11]
#
#
# Merging  [11]
#
# Splitting  [13]
#
#
# Merging  [13]
#
# Merging  [11, 13]
#
# Merging  [11, 12, 13]
#
# Splitting  [5, 6, 7]
#
#
# Splitting  [5]
#
#
# Merging  [5]
#
# Splitting  [6, 7]
#
#
# Splitting  [6]
#
#
# Merging  [6]
#
# Splitting  [7]
#
#
# Merging  [7]
#
# Merging  [6, 7]
#
# Merging  [5, 6, 7]
#
# Merging  [5, 6, 7, 11, 12, 13]
#
# Sorted array is: [5, 6, 7, 11, 12, 13]

# %% [markdown]
# ## 3. Compare running time between iterative and recursive merge sort

# %%
ns = np.linspace(100, 1000, 50, dtype=int)

# %%
# Copy your iterative merge sort function without printing anything

# %%
# Copy your recursive merge sort function without printing anything

# %% [markdown]
# ### Numerical elements are randomly selected (random list)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ts_mergesort_iter = [timeit.timeit('merge_sort_iterative(lst)',
                              setup=f'lst = random.sample(range({n} * 2), {n})',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_mergesort_recur = [timeit.timeit('merge_sort_recursive(lst)',
                              setup=f'lst = random.sample(range({n} * 2), {n})',
                              globals=globals(),
                              number=10)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_mergesort_iter, '.r-') # Red dot
plt.plot(ns, ts_mergesort_recur, '.g-') # Green dot
plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Merge Sort Iterative vs Recursive')
plt.legend(['Iterative', 'Recursive'])

# %% [markdown]
# ### List is sorted

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ts_mergesort_iter = [timeit.timeit('merge_sort_iterative(lst)',
                              setup=f'lst = list(range({n}))',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_mergesort_recur = [timeit.timeit('merge_sort_recursive(lst)',
                              setup=f'lst = list(range({n}))',
                              globals=globals(),
                              number=10)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_mergesort_iter, '.r-') # Red dot
plt.plot(ns, ts_mergesort_recur, '.g-') # Green dot
plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Merge Sort Iterative vs Recursive')
plt.legend(['Iterative', 'Recursive'])

# %% [markdown]
# ## Lab 8-4 Compare running time of all 4 sorting algorithms (Bubble, Selection, Insertion, Merge)

# %%
ns = np.linspace(100, 1000, 50, dtype=int)

# %% [markdown]
# ### 1. On random list

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ts_bubblesort = [timeit.timeit('bubble_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_insertsort = [timeit.timeit('insertion_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_selectsort = [timeit.timeit('selection_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_mergesort_recur = [timeit.timeit('merge_sort_recursive(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_bubblesort, '.r-') # Red dot
plt.plot(ns, ts_insertsort, '.b-') # Blue dot
plt.plot(ns, ts_selectsort, '.c-') # Cyan dot
plt.plot(ns, ts_mergesort_recur, '.g-') # Green dot

plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Sorting Algorithms on random list')
plt.legend(['Bubble Sort', 'Insertion Sort', 'Selection Sort', 'Merge Sort Recursive'])

# %% [markdown]
# ## 2. On sorted list

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ts_bubblesort = [timeit.timeit('bubble_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_insertsort = [timeit.timeit('insertion_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_selectsort = [timeit.timeit('selection_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_mergesort_recur = [timeit.timeit('merge_sort_recursive(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_bubblesort, '.r-') # Red dot
plt.plot(ns, ts_insertsort, '.b-') # Blue dot
plt.plot(ns, ts_selectsort, '.c-') # Cyan dot
plt.plot(ns, ts_mergesort_recur, '.g-') # Green dot

plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Sorting Algorithms on sorted list')
plt.legend(['Bubble Sort', 'Insertion Sort', 'Selection Sort', 'Merge Sort Recursive'])

# %% [markdown]
# ## 3. On reversed sorted list

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 6] # set size of plot

ts_bubblesort = [timeit.timeit('bubble_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_insertsort = [timeit.timeit('insertion_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_selectsort = [timeit.timeit('selection_sort(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

ts_mergesort_recur = [timeit.timeit('merge_sort_recursive(lst)',
                              setup=f'Add your code here',
                              globals=globals(),
                              number=10)
                for n in ns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(ns, ts_bubblesort, '.r-') # Red dot
plt.plot(ns, ts_insertsort, '.b-') # Blue dot
plt.plot(ns, ts_selectsort, '.c-') # Cyan dot
plt.plot(ns, ts_mergesort_recur, '.g-') # Green dot

plt.xlabel('Number of elements')
plt.ylabel('Time (s)')
plt.title('Sorting Algorithms on reversed sorted list')
plt.legend(['Bubble Sort', 'Insertion Sort', 'Selection Sort', 'Merge Sort Recursive'])
